# %% [markdown]
# # IPL Data Analysis Using Pandas AI

# %% [markdown]
# In this project we will use pandas ai to deal with analysis of ipl data and to solve complex problems using pandas ai to get answer to our problems

# %%
#!pip install numpy pandas pandasai
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('D:\\Drive into Analysis\\IPL Data Analysis\\1731674068078_TATA IPL 2025- Auction List -15.11.24.csv')
df.head(5)
# Out:
#    Sr.No.  Set No. 2025 Set First Name  Surname       Country Unnamed: 6  \
# 0       1        1       M1        Jos  Buttler       England        NaN
# 1       2        1       M1    Shreyas     Iyer         India        MCA
# 2       3        1       M1    Rishabh     Pant         India       DDCA
# 3       4        1       M1     Kagiso   Rabada  South Africa        NaN
# 4       5        1       M1   Arshdeep    Singh         India        PCA
#
#           DOB  Age    Specialism  ...           Unnamed: 11 Test caps  \
# 0  08/09/1990   34  WICKETKEEPER  ...    RIGHT ARM Off Spin      57.0
# 1  06/12/1994   30        BATTER  ...    RIGHT ARM Off Spin      14.0
# 2  04/10/1997   27        BATTER  ...    RIGHT ARM Off Spin      37.0
# 3  25/05/1995   29        BOWLER  ...        RIGHT ARM Fast      66.0
# 4  05/02/1999   26        BOWLER  ...  LEFT ARM Fast Medium       NaN
#
#    ODI caps  T20 caps    IPL  Previous IPLTeam(s) Unnamed: 17 Unnamed: 18  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573 entries, 0 to 572
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sr.No.               573 non-null    int64
#  1   Set No.              573 non-null    int64
#  2   2025 Set             573 non-null    object
#  3   First Name           573 non-null    object
#  4   Surname              573 non-null    object
#  5   Country              573 non-null    object
#  6   Unnamed: 6           365 non-null    object
#  7   DOB                  573 non-null    object
#  8   Age                  573 non-null    int64
#  9   Specialism           573 non-null    object
#  10  Unnamed: 10          573 non-null    object
#  11  Unnamed: 11          496 non-null    object
#  12  Test caps            136 non-null    float64
#  13  ODI caps             207 non-null    float64
#  14  T20 caps             219 non-null    float64
# ...

# %%
df.drop(columns=['Unnamed: 6','Unnamed: 18'],inplace=True)
df.rename(columns={'Unnamed: 10':'Batting Style','Unnamed: 11':'Bowling Style','Unnamed: 17':'Current_Team'},inplace='True')

# %%
df.isna().sum()
# Out:
# Sr.No.                   0
# Set No.                  0
# 2025 Set                 0
# First Name               0
# Surname                  0
# Country                  0
# DOB                      0
# Age                      0
# Specialism               0
# Batting Style            0
# Bowling Style           77
# Test caps              437
# ODI caps               366
# T20 caps               354
# IPL                    275
# Previous IPLTeam(s)    276
# Current_Team           197
# C/U/A                  177
# Price Rs               332
# dtype: int64

# %%
df.dtypes
# Out:
# Sr.No.                   int64
# Set No.                  int64
# 2025 Set                object
# First Name              object
# Surname                 object
# Country                 object
# DOB                     object
# Age                      int64
# Specialism              object
# Batting Style           object
# Bowling Style           object
# Test caps              float64
# ODI caps               float64
# T20 caps               float64
# IPL                    float64
# Previous IPLTeam(s)     object
# Current_Team            object
# C/U/A                   object
# Price Rs               float64
# dtype: object

# %%
df['DOB']=pd.to_datetime(df['DOB'],format="%d/%m/%Y")

# %%
df.dtypes
# Out:
# Sr.No.                          int64
# Set No.                         int64
# 2025 Set                       object
# First Name                     object
# Surname                        object
# Country                        object
# DOB                    datetime64[ns]
# Age                             int64
# Specialism                     object
# Batting Style                  object
# Bowling Style                  object
# Test caps                     float64
# ODI caps                      float64
# T20 caps                      float64
# IPL                           float64
# Previous IPLTeam(s)            object
# Current_Team                   object
# C/U/A                          object
# Price Rs                      float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
labels=['RHB','LHB']
plt.bar(labels,df['Batting Style'].value_counts(),color='blue')
plt.xlabel('Type of batsman')
plt.ylabel('Count')
plt.title('Total count of batman')
# Out:
# Text(0.5, 1.0, 'Total count of batman')

# %%
df.select_dtypes(include=['int64','float64']).corr()
# Out:
#              Sr.No.   Set No.       Age  Test caps  ODI caps  T20 caps  \
# Sr.No.     1.000000  0.999823 -0.173573  -0.194867 -0.213692 -0.173446
# Set No.    0.999823  1.000000 -0.173881  -0.194758 -0.215242 -0.175592
# Age       -0.173573 -0.173881  1.000000   0.516657  0.545466  0.421709
# Test caps -0.194867 -0.194758  0.516657   1.000000  0.725230  0.320812
# ODI caps  -0.213692 -0.215242  0.545466   0.725230  1.000000  0.735033
# T20 caps  -0.173446 -0.175592  0.421709   0.320812  0.735033  1.000000
# IPL       -0.378960 -0.382167  0.445277   0.512002  0.404148  0.231834
# Price Rs  -0.240797 -0.247512  0.417715   0.222872  0.287854  0.415574
#
#                 IPL  Price Rs
# Sr.No.    -0.378960 -0.240797
# Set No.   -0.382167 -0.247512
# Age        0.445277  0.417715
# Test caps  0.512002  0.222872
# ODI caps   0.404148  0.287854
# T20 caps   0.231834  0.415574
# IPL        1.000000  0.432605
# Price Rs   0.432605  1.000000

# %%
sns.regplot(x=df['IPL'],y=df['Price Rs'],color='b')
# Out:
# <Axes: xlabel='IPL', ylabel='Price Rs'>

# %%
df.isna().sum()
# Out:
# Sr.No.                   0
# Set No.                  0
# 2025 Set                 0
# First Name               0
# Surname                  0
# Country                  0
# DOB                      0
# Age                      0
# Specialism               0
# Batting Style            0
# Bowling Style           77
# Test caps              437
# ODI caps               366
# T20 caps               354
# IPL                    275
# Previous IPLTeam(s)    276
# Current_Team           197
# C/U/A                  177
# Price Rs               332
# dtype: int64

# %%
df['Test caps'].fillna(0,inplace=True)
df['Bowling Style'].fillna('None',inplace=True)
df['ODI caps'].fillna(0,inplace=True)
df['T20 caps'].fillna(0,inplace=True)
df['Current_Team'].fillna('None',inplace=True)
df['Previous IPLTeam(s)'].fillna('None',inplace=True)
df['C/U/A'].fillna('None',inplace=True)
df['IPL'].fillna('None',inplace=True)
avg=df['Price Rs'].value_counts().idxmax()
df['Price Rs'].fillna(avg,inplace=True)
# Out:
# C:\Users\Mayank chouhan\AppData\Local\Temp\ipykernel_2356\3665209245.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Test caps'].fillna(0,inplace=True)
# C:\Users\Mayank chouhan\AppData\Local\Temp\ipykernel_2356\3665209245.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isna().sum()
# Out:
# Sr.No.                 0
# Set No.                0
# 2025 Set               0
# First Name             0
# Surname                0
# Country                0
# DOB                    0
# Age                    0
# Specialism             0
# Batting Style          0
# Bowling Style          0
# Test caps              0
# ODI caps               0
# T20 caps               0
# IPL                    0
# Previous IPLTeam(s)    0
# Current_Team           0
# C/U/A                  0
# Price Rs               0
# dtype: int64

# %%
df.dtypes
# Out:
# Sr.No.                          int64
# Set No.                         int64
# 2025 Set                       object
# First Name                     object
# Surname                        object
# Country                        object
# DOB                    datetime64[ns]
# Age                             int64
# Specialism                     object
# Batting Style                  object
# Bowling Style                  object
# Test caps                     float64
# ODI caps                      float64
# T20 caps                      float64
# IPL                            object
# Previous IPLTeam(s)            object
# Current_Team                   object
# C/U/A                          object
# Price Rs                      float64
# dtype: object

# %%
df.describe()
# Out:
#            Sr.No.     Set No.                            DOB         Age  \
# count  573.000000  573.000000                            573  573.000000
# mean   287.000000   40.263525  1997-07-04 06:24:30.157068032   27.294939
# min      1.000000    1.000000            1982-07-30 00:00:00   14.000000
# 25%    144.000000   21.000000            1994-02-21 00:00:00   24.000000
# 50%    287.000000   40.000000            1997-12-29 00:00:00   27.000000
# 75%    430.000000   60.000000            2001-02-04 00:00:00   31.000000
# max    573.000000   79.000000            2011-03-27 00:00:00   42.000000
# std    165.555127   22.613166                            NaN    4.834165
#
#         Test caps    ODI caps    T20 caps    Price Rs
# count  573.000000  573.000000  573.000000  573.000000
# mean     6.120419   15.342059   13.855148   60.680628
# min      0.000000    0.000000    0.000000   30.000000
# 25%      0.000000    0.000000    0.000000   30.000000
# ...

# %%
df.head(5)
# Out:
#    Sr.No.  Set No. 2025 Set First Name  Surname       Country        DOB  Age  \
# 0       1        1       M1        Jos  Buttler       England 1990-09-08   34
# 1       2        1       M1    Shreyas     Iyer         India 1994-12-06   30
# 2       3        1       M1    Rishabh     Pant         India 1997-10-04   27
# 3       4        1       M1     Kagiso   Rabada  South Africa 1995-05-25   29
# 4       5        1       M1   Arshdeep    Singh         India 1999-02-05   26
#
#      Specialism Batting Style         Bowling Style  Test caps  ODI caps  \
# 0  WICKETKEEPER           RHB    RIGHT ARM Off Spin       57.0     181.0
# 1        BATTER           RHB    RIGHT ARM Off Spin       14.0      62.0
# 2        BATTER           LHB    RIGHT ARM Off Spin       37.0      31.0
# 3        BOWLER           RHB        RIGHT ARM Fast       66.0     101.0
# 4        BOWLER           LHB  LEFT ARM Fast Medium        0.0       8.0
#
# ...

# %%
m=df.groupby('Current_Team')['Batting Style'].count()
print(m)
# Out:
# Current_Team
# Associate      1
# CSK           21
# Capped        55
# DC            22
# GT            22
# KKR           17
# LSG           19
# MI            22
# Mi             1
# None         197
# PBKS          19
# RCB           19
# RR            17
# SRH           20
# Uncapped     121
# Name: Batting Style, dtype: int64
