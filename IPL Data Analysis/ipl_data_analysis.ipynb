# %% [markdown]
# # IPL Data Analysis Using Pandas AI

# %% [markdown]
# In this project we will use pandas ai to deal with analysis of ipl data and to solve complex problems using pandas ai to get answer to our problems

# %%
#!pip install numpy pandas pandasai
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('D:\\Drive into Analysis\\IPL Data Analysis\\1731674068078_TATA IPL 2025- Auction List -15.11.24.csv')
df.head(10)
# Out:
#    Sr.No.  Set No. 2025 Set First Name      Surname       Country Unnamed: 6  \
# 0       1        1       M1        Jos      Buttler       England        NaN
# 1       2        1       M1    Shreyas         Iyer         India        MCA
# 2       3        1       M1    Rishabh         Pant         India       DDCA
# 3       4        1       M1     Kagiso       Rabada  South Africa        NaN
# 4       5        1       M1   Arshdeep        Singh         India        PCA
# 5       6        1       M1   Mitchell        Starc     Australia        NaN
# 6       7        2       M2  Yuzvendra       Chahal         India        HCA
# 7       8        2       M2       Liam  Livingstone       England        NaN
# 8       9        2       M2      David       Miller  South Africa        NaN
# 9      10        2       M2         KL        Rahul         India       KSCA
#
#           DOB  Age    Specialism  ...           Unnamed: 11 Test caps  \
# ...

# %%
df.drop(columns=['Unnamed: 6'],axis=1,inplace=True)
df.head(2)
# Out:
#    Sr.No.  Set No. 2025 Set First Name  Surname  Country         DOB  Age  \
# 0       1        1       M1        Jos  Buttler  England  08/09/1990   34
# 1       2        1       M1    Shreyas     Iyer    India  06/12/1994   30
#
#      Specialism Unnamed: 10         Unnamed: 11  Test caps  ODI caps  \
# 0  WICKETKEEPER         RHB  RIGHT ARM Off Spin       57.0     181.0
# 1        BATTER         RHB  RIGHT ARM Off Spin       14.0      62.0
#
#    T20 caps    IPL Previous IPLTeam(s) Unnamed: 17 Unnamed: 18   C/U/A  \
# 0     124.0  107.0               MI,RR          RR          11  Capped
# 1      51.0  116.0              DC,KKR         KKR          15  Capped
#
#    Price Rs
# 0     200.0
# 1     200.0

# %%
df.isna().sum()
# Out:
# Sr.No.                   0
# Set No.                  0
# 2025 Set                 0
# First Name               0
# Surname                  0
# Country                  0
# DOB                      0
# Age                      0
# Specialism               0
# Unnamed: 10              0
# Unnamed: 11             77
# Test caps              437
# ODI caps               366
# T20 caps               354
# IPL                    275
# Previous IPLTeam(s)    276
# Unnamed: 17            197
# Unnamed: 18             42
# C/U/A                  177
# Price Rs               332
# dtype: int64

# %%
avg=int(df['Price Rs'].mean())-2
df['Price Rs'].fillna(avg,inplace=True)
# Out:
# C:\Users\Mayank chouhan\AppData\Local\Temp\ipykernel_32284\2456164692.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price Rs'].fillna(avg,inplace=True)

# %%
df.isna().sum()
# Out:
# Sr.No.                   0
# Set No.                  0
# 2025 Set                 0
# First Name               0
# Surname                  0
# Country                  0
# DOB                      0
# Age                      0
# Specialism               0
# Unnamed: 10              0
# Unnamed: 11             77
# Test caps              437
# ODI caps               366
# T20 caps               354
# IPL                    275
# Previous IPLTeam(s)    276
# Unnamed: 17            197
# Unnamed: 18             42
# C/U/A                  177
# Price Rs                 0
# dtype: int64

# %%
# df.rename(columns={'Unnamed: 10':''})
value=df['Unnamed: 18'].value_counts().idxmax()
df['Unnamed: 18'].fillna(value,inplace=True)
# Out:
# C:\Users\Mayank chouhan\AppData\Local\Temp\ipykernel_32284\130901237.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Unnamed: 18'].fillna(value,inplace=True)

# %%
# df['Unnamed: 18']=df['Unnamed: 18'].astype(float)
df.isna().sum()
# Out:
# Sr.No.                   0
# Set No.                  0
# 2025 Set                 0
# First Name               0
# Surname                  0
# Country                  0
# DOB                      0
# Age                      0
# Specialism               0
# Unnamed: 10              0
# Unnamed: 11             77
# Test caps              437
# ODI caps               366
# T20 caps               354
# IPL                    275
# Previous IPLTeam(s)    276
# Unnamed: 17            197
# Unnamed: 18              0
# C/U/A                  177
# Price Rs                 0
# dtype: int64

# %%
df.loc[141:190,'Unnamed: 18']
# Out:
# 141     0
# 142     1
# 143     0
# 144     0
# 145     1
# 146    30
# 147     0
# 148     1
# 149     3
# 150    30
# 151     0
# 152     0
# 153    30
# 154     3
# 155    30
# 156     1
# 157     8
# 158     0
# 159     2
# 160    30
# 161    16
# 162     8
# 163    13
# 164    11
# 165     8
# 166     7
# 167     5
# 168     6
# 169    30
# 170    30
# 171    30
# 172    30
# 173    30
# 174    30
# 175    30
# 176    30
# 177     6
# 178     5
# 179     1
# 180     9
# 181     9
# 182     7
# 183    10
# 184    11
# 185     7
# 186    30
# 187    30
# 188    30
# 189    30
# 190    30
# Name: Unnamed: 18, dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Sr.No.                   0
# Set No.                  0
# 2025 Set                 0
# First Name               0
# Surname                  0
# Country                  0
# DOB                      0
# Age                      0
# Specialism               0
# Unnamed: 10              0
# Unnamed: 11             77
# Test caps              437
# ODI caps               366
# T20 caps               354
# IPL                    275
# Previous IPLTeam(s)    276
# Unnamed: 17            197
# Unnamed: 18              0
# C/U/A                  177
# Price Rs                 0
# dtype: int64

# %%
df['Test caps'].replace(np.NaN,0,inplace=True)
# Out:
# C:\Users\Mayank chouhan\AppData\Local\Temp\ipykernel_32284\2398833540.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Test caps'].replace(np.NaN,0,inplace=True)

# %%
df.isna().sum()
# Out:
# Sr.No.                   0
# Set No.                  0
# 2025 Set                 0
# First Name               0
# Surname                  0
# Country                  0
# DOB                      0
# Age                      0
# Specialism               0
# Unnamed: 10              0
# Unnamed: 11             77
# Test caps                0
# ODI caps               366
# T20 caps               354
# IPL                    275
# Previous IPLTeam(s)    276
# Unnamed: 17            197
# Unnamed: 18              0
# C/U/A                  177
# Price Rs                 0
# dtype: int64

# %%
df.head(5)
# Out:
#    Sr.No.  Set No. 2025 Set First Name  Surname       Country         DOB  \
# 0       1        1       M1        Jos  Buttler       England  08/09/1990
# 1       2        1       M1    Shreyas     Iyer         India  06/12/1994
# 2       3        1       M1    Rishabh     Pant         India  04/10/1997
# 3       4        1       M1     Kagiso   Rabada  South Africa  25/05/1995
# 4       5        1       M1   Arshdeep    Singh         India  05/02/1999
#
#    Age    Specialism Unnamed: 10           Unnamed: 11  Test caps  ODI caps  \
# 0   34  WICKETKEEPER         RHB    RIGHT ARM Off Spin       57.0     181.0
# 1   30        BATTER         RHB    RIGHT ARM Off Spin       14.0      62.0
# 2   27        BATTER         LHB    RIGHT ARM Off Spin       37.0      31.0
# 3   29        BOWLER         RHB        RIGHT ARM Fast       66.0     101.0
# 4   26        BOWLER         LHB  LEFT ARM Fast Medium        0.0       8.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573 entries, 0 to 572
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sr.No.               573 non-null    int64
#  1   Set No.              573 non-null    int64
#  2   2025 Set             573 non-null    object
#  3   First Name           573 non-null    object
#  4   Surname              573 non-null    object
#  5   Country              573 non-null    object
#  6   DOB                  573 non-null    object
#  7   Age                  573 non-null    int64
#  8   Specialism           573 non-null    object
#  9   Unnamed: 10          573 non-null    object
#  10  Unnamed: 11          496 non-null    object
#  11  Test caps            573 non-null    float64
#  12  ODI caps             207 non-null    float64
#  13  T20 caps             219 non-null    float64
#  14  IPL                  298 non-null    float64
# ...

# %%
df.rename(columns={'Unnamed: 10':'Batting Style','Unnamed: 11':'Bowling Style'},inplace=True)
